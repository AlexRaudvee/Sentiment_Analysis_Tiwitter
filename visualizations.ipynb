# %% [markdown]
# # This file is for visualizations

# %% [markdown]
# ### import the variables

# %%
from ipynb.fs.full.main import *
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Succesfuly connected to the database
# ---TABLE NAMES IN DB---
# -----------------------
# users
# -----------------------
# tweets
# -----------------------
# tweets_geo
# -----------------------
# replies
# -----------------------
# retweets
# -----------------------
# quotes
# -----------------------
# hashtags
# -----------------------
# sqlite_sequence
# -----------------------
# symbols
# -----------------------
# user_mentions
# -----------------------
# ...

# %%
from ipynb.fs.full.sentiment_analysis import *
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Succesfuly connected to the database
# ---TABLE NAMES IN DB---
# -----------------------
# users
# -----------------------
# tweets
# -----------------------
# tweets_geo
# -----------------------
# replies
# -----------------------
# retweets
# -----------------------
# quotes
# -----------------------
# hashtags
# -----------------------
# sqlite_sequence
# -----------------------
# symbols
# -----------------------
# user_mentions
# -----------------------
# ...
